# %%
class Usuario():

    def setInformacion_Personal(self, nombre, identificacion, edad, telefono):
        
        self.nombre = nombre
        self.identificacion = identificacion
        self.edad = edad
        self.telefono = telefono
    
    def getnombre(self):
        return self.nombre
    
    def get_identificacion(self):
        return self.identificacion

    def get_edad(self):
        return self.edad

    def get_telefono(self):
        return self.telefono

class libro(Usuario):

    def pedir_libro(self, Libro_Prestado):
        self.s=3
        self.Libro_Prestado = Libro_Prestado
        if self.Libro_Prestado == "don quijote de la mancha":
            self.s=0
        if self.Libro_Prestado == "bajo la misma estrella":
            self.s=1
        if self.Libro_Prestado == "bajo el mismo cielo":
            self.s=2
        if self.s==3:
          print("============")
          print("Libro no encontrado")
          self.pedir_libro(input("¿Que libro quiere prestar?"))

    def Datos_libro(self):
        print(f'Titulo:{libros[self.s]["titulo"]}')
        print(f'edicion:{libros[self.s]["edicion"]}')
        print(f'Autor: {libros[self.s]["autor"]}')
        print(f'ISBN: {libros[self.s]["ISBN"]}')
        print(f'{libros[self.s]["lugar"]}, {libros[self.s]["fecha_edicion"]}')
        print(f'{libros[self.s]["paginas"]} paginas')
        print(f'editorial:{libros[self.s]["editorial"]}')
class Prestar_libro(libro):

    def Libros_Disponibles(self):
        print("ESTOS SON LOS LIBROS DISPONIBLES:")
        print("============")
        print(libros[0]["titulo"])
        print(libros[1]["titulo"])
        print(libros[2]["titulo"])

    def mostrar_Informacion(self):
        self.pedir_libro(input("¿que libro vas a prestar?"))
        print("=============")
        print(f'{self.getnombre()} : con el numero de identificacion: {self.get_identificacion()}  ha prestado el siguiente libro:')
        self.Datos_libro()

libros = [{'titulo':'Don quijote de la mancha', 
           'autor':'Miguel de cervantes', 
           'ISBN':'0-13-031997-x',
           'paginas':'1346', 
           'edicion':'3a.edicion',
           'editorial':'Porrúa S.A. de C.V.:',
           'lugar':'inglaterra', 
           'fecha_edicion':'12/09/1987'},
           {'titulo':'Bajo la misma estrella', 
            'autor':'John Green',
            'ISBN':'9585783010',
            'paginas':'304',
            'edicion':'Unknown', 
            'editorial':'Nube De Tinta', 
            'lugar':'España',
            'fecha_edicion':'2014'},
           {'titulo':'bajo el mismo cielo', 
            'autor':'Vegetta777; Willyrex', 
            'ISBN':'978-84-9998-524-4', 
            'paginas':'192', 
            'edicion':'3a.edidicion',
            'editorial':'Temas De Hoy',
            'lugar':'Barcelona', 
            'fecha_edicion':'15 de marzo de 2016','editorial':'precentice-hall'}]
            

persona = Prestar_libro()
print("BIENVENIDOS")
print("==============")
print("LIBRERIA FET")
print("==============")
persona.setInformacion_Personal(str(input('Escriba su nombre:')),
                                (input('Escriba su identificacion:')), 
                                int(input('Escriba su edad:')),
                                int(input('Escriba su telefono:')))
print("==============")
persona.Libros_Disponibles()
print("==============")
persona.mostrar_Informacion()

# %%
class Nequi:
    dinero=0
    cuanta_ahorro=0
    def meter(self):
        dinero_meter=int(input("puedes ingresar la  cantidad de dinero a guardar"))
        self.dinero=self.dinero+dinero_meter
        print(f"se te ha guardado el dinero, actualmente hay $ {self.dinero} en su cuenta")
    def sacar(self):
        dinero_sacar=int(input("ingrese la  totalidad de dinero que pueda retirar"))
        self.dinero=self.dinero-dinero_sacar
        print(f"RETIRASTE CORECTAMENTE EL DINERO TIENES {self.dinero} EN TU CUENTA")
        while self.dinero<dinero_sacar:
            print("no se puede retirar dinero ya que la cantidad que desea es mayor")
            dinero_sacar=int(input(f"tiene $ {self.dinero}, ingrese la cantidad de dinero que desee retirar"))
        self.dinero=self.dinero-dinero_sacar


class Usuarios(Nequi):
    def __init__(self):
        self.usuario=[]
        self.contraseña=[]
        self.cedula=[]
        self.nombre=[]
        self.apellido=[]
        self.contraseña_ahorro=[]

    def registrar(self):
        self.usuario.append(str(input("ingresar su numero de telefono:")))
        self.contraseña.append(str(input("ingrese una contraseña :")))
        self.cedula.append(str(input('ingrese su cedula:')))
        self.nombre.append(str(input("ingrese su nombre:")))
        self.apellido.append(str(input("ingrese su apellido:")))
        print("usuario registrado:")
        print("\tUsuario:",self.usuario)
        print("\tnombre:",self.nombre,self.apellido,"\n")

    def mostrar_usuario(self):
        return self.usuario
        
    def verificar_su_contraseña(self):
        while True:
            contraseñaaverificar=[]
            contraseñaaverificar.append(str(input("digite tu contraseña:")))
            if contraseñaaverificar==self.contraseña:
                break
        print("contraseña:",contraseñaaverificar)

    def crea_cuentas (self):
        self.contraseña_ahorro.append(str(input("se utilizaran los datos de la cuenta actual para crear la cuenta de ahorro, a continuacion cree una contraseña para la cuenta de ahorro:")))
        print(f"cuenta de ahorro creada\n\tUsuario: {self.usuario} \n\tContraseña: {self.contraseña_ahorro}")
        while True:
            salir_ca=int(input("presione (1) para vover a la cuenta principal:"))
            if salir_ca==1:
                break

    

class Ingresar(Usuarios):
    def entrar(self):
        if opcion_usuario==1:
            print("Usuario:",usuario1.mostrar_usuario())
            usuario1.verificar_su_contraseña()
            while True:
                while True:
                    opcion_realizar=int(input("elija la opcion. (1)guardar dinero (2)retirar dinero (3)desea crear una cuenta ahorro (4)cerrar seccion:"))
                    if opcion_realizar>0 and opcion_realizar<5:
                        break
                if opcion_realizar==1:
                    usuario1.meter()
                elif opcion_realizar==2:
                    usuario1.sacar()
                elif opcion_realizar==3:
                    usuario1.crea8_ca()
                    print("te encuentras en la cuenta oficial:")
                elif opcion_realizar==4:
                    print("Se dio a cerrar seccion:")
                    break

        else:
            print("Usuario:",usuario2.mostrar_usuario()) 
            usuario2.verificar_su_contraseña()
            while True:
                while True:
                    opcion_realizar=int(input("elija la opcion. (1)guardar dinero (2)retirar dinero (3)desea crear una cuenta de ahorro (43)cerrar seccion"))
                    if opcion_realizar>0 and opcion_realizar<5:
                        break
                if opcion_realizar==1:
                    usuario2.meter()
                elif opcion_realizar==2:
                    usuario2.sacar()
                elif opcion_realizar==3:
                    usuario2.crea_cuentas()
                    print("te encuentras nuevamente en la cuenta oficial")
                elif opcion_realizar==4:
                    print("seccion cerrada")
                    break

usuario1=Ingresar()
usuario2=Ingresar()
print("usuario 1")
usuario1.registrar()
print("usuario 2")
usuario2.registrar()

print("BIENVENIDOS MINI NEQUI CRISTIAN")
while True:
    while True:
        opcion_usuario=int(input('con cual usuario desea ingresar? (1 o 2),puede presionar (0) para salir de "Nequi"'))
        if opcion_usuario<3:
            break
    while opcion_usuario<0 and opcion_usuario>2:
        opcion_usuario=int(input("opcion no valida, ingrese la correcta (1 o 2)"))
    if opcion_usuario==1:
        usuario2.entrar()
    elif opcion_usuario==2:
        usuario2.entrar()
    else:
        break
# Out:
# usuario 1
# ingresar su numero de telefono:123456
# ingrese una contraseña :123
# ingrese su cedula:234567
# ingrese su nombre:cristiqn
# ingrese su apellido:sarmirnto
# usuario registrado:
# 	Usuario: ['123456']
# 	nombre: ['cristiqn'] ['sarmirnto']
#
# usuario 2
# ingresar su numero de telefono:123456
# ingrese una contraseña :123
# ingrese su cedula:23456
# ingrese su nombre:csdfgh
# ingrese su apellido:werty
# usuario registrado:
# 	Usuario: ['123456']
# 	nombre: ['csdfgh'] ['werty']
#
# BIENVENIDOS MINI NEQUI CRISTIAN
# con cual usuario desea ingresar? (1 o 2),puede presionar (0) para salir de "Nequi"2
# Usuario: ['123456']
# digite tu contraseña:123
# contraseña: ['123']
# elija la opcion. (1)guardar dinero (2)retirar dinero (3)desea crear una cuenta de ahorro (43)cerrar seccion3
# se utilizaran los datos de la cuenta actual para crear la cuenta de ahorro, a continuacion cree una contraseña para la cuenta de ahorro:123
# cuenta de ahorro creada
# 	Usuario: ['123456']
# ...

# %% [markdown]
# DIAGRAMA
# ![BPMN 2.0 (5).png](data:image/png;base64,...)
